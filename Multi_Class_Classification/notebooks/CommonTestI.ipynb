# %%
# MultiClass_CNN_Workflow.ipynb
# --------------------------------------------
# Master notebook to run all 5 steps
# using existing scripts
# --------------------------------------------

# Step 0: Setup
# --------------------------------------------
import os
import matplotlib.pyplot as plt

# Ensure paths are correct
scripts_path = '../scripts'
results_path = '../results'
os.makedirs(results_path, exist_ok=True)

print("Ready to run all steps!")

# --------------------------------------------
# Step 1: Load & Visualize
# --------------------------------------------
print("Running Step 1: Load & Visualize Dataset...")
# %run ../scripts/step1_load_visualize.py

# --------------------------------------------
# Step 2: DataLoader
# --------------------------------------------
print("Running Step 2: DataLoader...")
# %run ../scripts/step2_dataloader.py

# --------------------------------------------
# Step 3: Train CNN
# --------------------------------------------
print("Running Step 3: Train CNN...")
# %run ../scripts/step3_train_cnn.py

# --------------------------------------------
# Step 4: Evaluate Model
# --------------------------------------------
print("Running Step 4: Evaluate Model...")
# %run ../scripts/step4_evaluate.py

# --------------------------------------------
# Step 5: Predict New Images
# --------------------------------------------
print("Running Step 5: Predict New Images...")
# %run ../scripts/step5_predict.py

# --------------------------------------------
# All steps complete
# --------------------------------------------
print("All steps executed successfully!")
print(f"Results saved in: {results_path}")
# Out:
# Ready to run all steps!
# Running Step 1: Load & Visualize Dataset...
# Classes: ['no_substructure', 'subhalo', 'vortex']
# Total images: 30000
# Example image shape: torch.Size([1, 150, 150])
# Training images: 27000
# Test images: 3000
# Running Step 2: DataLoader...
# Batch image shape: torch.Size([32, 1, 150, 150])
# Batch labels shape: torch.Size([32])
# Running Step 3: Train CNN...
# Using device: cpu
